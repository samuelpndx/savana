# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
#df = pd.read_csv ('2019-03-07__03-00-26.sav', header=None, comment='*', sep='\s+', engine='python', na_values="-99999|-9999")
#df.head()

# %%
df = pd.read_csv ('2019-03-07__03-00-26.sav', header=None, comment='\t', delim_whitespace=True, low_memory=False, na_values=(-9999, -99999))

# %%
pd.set_option('display.max_columns', 70)

# %%
df
# Out:
#                 0   1   2     3        4        5        6         7   8   \
# 0       2019-03-07   0   3   4.2  1.43050  0.33900  0.74175  27.83771  35
# 1       2019-03-07   0   3   4.3  1.42875  0.30025  0.78175  27.83078  36
# 2       2019-03-07   0   3   4.4  1.43725  0.30475  0.76425  27.79788  37
# 3       2019-03-07   0   3   4.5  1.47625  0.35275  0.74150  27.81177  38
# 4       2019-03-07   0   3   4.6  1.53300  0.38000  0.74325  27.84119  39
# 5       2019-03-07   0   3   4.7  1.55175  0.44525  0.70000  27.85156  40
# 6       2019-03-07   0   3   4.8  1.58400  0.52475  0.66025  27.84464  41
# 7       2019-03-07   0   3   4.9  1.53350  0.50125  0.63925  27.84985  42
# 8       2019-03-07   0   3   5.0  1.47575  0.51250  0.74600  27.86887  43
# 9       2019-03-07   0   3   5.1  1.44350  0.52950  0.77675  27.84464  44
# 10      2019-03-07   0   3   5.2  1.41525  0.50825  0.78925  27.84811  45
# 11      2019-03-07   0   3   5.3  1.45825  0.48875  0.74725  27.82211  46
# ...

# %%
pd.set_option('display.max_columns', 75)
new_df = df.dropna(axis=1, how="all")

# %%
df.loc[[1]]

# %%
new_df

# %%
for i in range(len(df.columns)):
    fig = plt.figure(figsize=(12,7))
    #ax = fig.add_subplot(1, 1, 1)
    #ax.plot(df[67])
    plt.plot(df[i])
    plt.tight_layout()
    fig.savefig(str(i) + ".png")
    plt.close(fig)

# %%
plt.hist(df[7])

# %%
plt.plot(df[20])
plt.plot(df[21])
plt.plot(df[22])

# %%
plt.plot(df[9])

# %%
plt.plot(df[10])

# %%
df.describe()
# Out:
#                   1              2              3              4   \
# count  864250.000000  864250.000000  864250.000000  864250.000000
# mean       11.498183      29.495933      29.947725       2.332448
# std         6.922919      17.319775      17.321052       1.240940
# min         0.000000       0.000000       0.000000      -1.315500
# 25%         5.000000      14.000000      14.900000       1.455250
# 50%        11.000000      29.000000      29.900000       2.201750
# 75%        17.000000      44.000000      44.900000       3.069000
# max        23.000000      59.000000      59.900000      11.543000
#
#                   5              6              7              8   \
# count  864250.000000  864250.000000  864250.000000  864250.000000
# mean       -0.260455       0.066886      27.937466      31.500676
# std         1.052429       0.525830       1.317670      18.473237
# min        -7.167501      -4.278250      26.071320       0.000000
# ...
